# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Load the data

# %%
movie_metadata = pd.read_csv('MovieSummaries/movie.metadata.tsv',sep='\t')

movie_metadata.columns = ['1. Wikipedia movie ID',
                          '2. Freebase movie ID',
                          '3. Movie name',
                          '4. Movie release date',
                          '5. Movie box office revenue',
                          '6. Movie runtime',
                          '7. Movie languages (Freebase ID:name tuples)',
                          '8. Movie countries (Freebase ID:name tuples)',
                          '9. Movie genres (Freebase ID:name tuples)']

character_metadata = pd.read_csv('MovieSummaries/character.metadata.tsv',sep='\t')

character_metadata.columns = ['1. Wikipedia movie ID',
                              '2. Freebase movie ID',
                              '3. Movie release date',
                              '4. Character name',
                              '5. Actor date of birth',
                              '6. Actor gender',
                              '7. Actor height (in meters)',
                              '8. Actor ethnicity (Freebase ID)',
                              '9. Actor name',
                              '10. Actor age at movie release',
                              '11. Freebase character/actor map ID',
                              '12. Freebase character ID',
                              '13. Freebase actor ID']

display(movie_metadata)
display(character_metadata)
# Out:
#        1. Wikipedia movie ID 2. Freebase movie ID  \
# 0                    3196793            /m/08yl5d
# 1                   28463795           /m/0crgdbh
# 2                    9363483           /m/0285_cd
# 3                     261236            /m/01mrr1
# 4                   13696889           /m/03cfc81
# ...                      ...                  ...
# 81735               35228177           /m/0j7hxnt
# 81736               34980460           /m/0g4pl34
# 81737                9971909           /m/02pygw1
# 81738                 913762            /m/03pcrp
# 81739               12476867           /m/02w7zz8
#
#                                            3. Movie name  \
# 0      Getting Away with Murder: The JonBenét Ramsey ...
# 1                                            Brun bitter
# 2                                       White Of The Eye
# 3                                      A Woman in Flames
# 4                                          The Gangsters
# ...

# %%
# We have a outlier at year 1010

# Create a copy
movie_metadata_ex = movie_metadata.copy(deep=true)

# Take off the nan values and just see the first 4 numbers (years)
year_release = (movie_metadata_ex['4. Movie release date'].dropna()).astype(str).str[:4]

# Count the numbers that are equal
year_release = year_release.value_counts()

# Sort the Years
year_release = year_release.sort_index()
print(str("The earliest film is from the year ")+str(np.min(year_release.index))+str(", which doesn't make sense therefore we discard it"))

#We drop year 1010
year_release=year_release[1:]

#The indices of the panda series are strings, therefore we put them into a list and convert them to int in order to be able to
#change the frequency of xticks
year_indices = year_release.index.values.tolist()
year_indices = [int(s) for s in year_indices]

# Create a histogram
plt.figure(figsize=(12, 6))
plt.bar(year_indices, year_release.values)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Movies Released Per Year')

#The x-axis values overlap, we therefore seperate it by using a custom range
plt.xticks(np.arange(min(year_indices), max(year_indices), 5), rotation=45)
plt.show()
# Out:
# The earliest film is from the year 1010, which doesn't make sense therefore we discard it

# %%
# Indicator variable showing that something is NA
df_analysis=movie_metadata.copy(deep=True)
df_analysis["4. Movie release date"]=df_analysis["4. Movie release date"].dropna().astype(str).str[:4]

#print(df_analysis.columns)
columns_list=df_analysis.columns
fig,ax= plt.subplots(1,2, figsize=(15,7))

for i in range(0,2):

    for column_name, index in zip(columns_list, range(0, len(columns_list))):
        print(column_name)

        df_analysis["missing_data"] = df_analysis[column_name].notna()
        mean_missing=df_analysis["missing_data"].mean()

        # Simple plot
        ax[i].bar(column_name,mean_missing)

    ax[i].set_ylabel("Percentage")
    ax[i].set_xlabel("Columns")
    ax[i].set_xticklabels(ax[i].get_xticks(), rotation = 50)
    ax[i].set_title(f"Missing data for {column_name}");



#We observe that a lot of box office data are missing, we are gonna scrape the missing data with BoxOfficeMojo
# Out:
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie name
# 4. Movie release date
# 5. Movie box office revenue
# 6. Movie runtime
# 7. Movie languages (Freebase ID:name tuples)
# 8. Movie countries (Freebase ID:name tuples)
# 9. Movie genres (Freebase ID:name tuples)
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie name
# 4. Movie release date
# 5. Movie box office revenue
# 6. Movie runtime
# 7. Movie languages (Freebase ID:name tuples)
# 8. Movie countries (Freebase ID:name tuples)
# 9. Movie genres (Freebase ID:name tuples)
# C:\Users\mriza\AppData\Local\Temp\ipykernel_36836\1802655921.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticks(), rotation = 50)
# ...

# %% [markdown]
# We observe that the majority of the box office data is missing. In order to visualize it better, we are going to look at the year by year evolution of the missing data

# %%
# Indicator variable showing that something is NA
df_analysis["4. Movie release date"]=df_analysis["4. Movie release date"].dropna().astype(str).str[:4]

df_analysis["boffice_is_na"] = df_analysis["5. Movie box office revenue"].isna()
missing_boffice_data = df_analysis.groupby("4. Movie release date")["boffice_is_na"].mean()
index_values=missing_boffice_data.index.values.tolist()
index_values = [int(s) for s in index_values[1:]]

# Simple plot
plt.plot(index_values, missing_boffice_data[1:])
plt.ylabel("Percentage")
plt.xlabel("Year")
plt.xticks(np.arange(min(index_values), max(index_values)+1, 10),rotation=45)
plt.title("Percentage missing box office data per year");

#We observe that a lot of box office data are missing, we are gonna scrape the missing data with BoxOfficeMojo

# %%
# Indicator variable showing that something is NA
df_analysis=character_metadata.copy(deep=True)
df_analysis["3. Movie release date"]=df_analysis["3. Movie release date"].dropna().astype(str).str[:4]

#print(df_analysis.columns)
columns_list=df_analysis.columns
fig,ax= plt.subplots(1,2, figsize=(15,7))

for i in range(0,2):

    for column_name, index in zip(columns_list, range(0, len(columns_list))):
        print(column_name)

        df_analysis["missing_data"] = df_analysis[column_name].notna()
        mean_missing=df_analysis["missing_data"].mean()

        # Simple plot
        ax[i].bar(column_name,mean_missing)

    ax[i].set_ylabel("Percentage")
    ax[i].set_xlabel("Columns")
    ax[i].set_xticklabels(ax[i].get_xticks(), rotation = 50)
    ax[i].set_title(f"Missing data for {column_name}");



#We observe that a lot of box office data are missing, we are gonna scrape the missing data with BoxOfficeMojo
# Out:
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie release date
# 4. Character name
# 5. Actor date of birth
# 6. Actor gender
# 7. Actor height (in meters)
# 8. Actor ethnicity (Freebase ID)
# 9. Actor name
# 10. Actor age at movie release
# 11. Freebase character/actor map ID
# 12. Freebase character ID
# 13. Freebase actor ID
# C:\Users\mriza\AppData\Local\Temp\ipykernel_36836\4119519704.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticks(), rotation = 50)
# C:\Users\mriza\AppData\Local\Temp\ipykernel_36836\4119519704.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticks(), rotation = 50)
# 1. Wikipedia movie ID
# 2. Freebase movie ID
# 3. Movie release date
# 4. Character name
# 5. Actor date of birth
# 6. Actor gender
# ...

# %%
cmeta_copy=character_metadata.copy(deep=True)
#cmeta_copy=cmeta_copy.dropna(subset=["2. Freebase movie ID", "6. Actor gender"]
cmeta_copy_grouped=cmeta_copy.groupby(by="2. Freebase movie ID")["6. Actor gender"]

for year, gender in cmeta_copy_grouped:
    
print(cmeta_copy_grouped)

# %%
#We first drop the rows where either box office revenue or year data is missing
movie_metadata_dropped=movie_metadata.dropna(subset=['5. Movie box office revenue', '4. Movie release date'])

#We then take the first 4 digits of the year which correspond to the year
movie_metadata_dropped.loc[:, '4. Movie release date']=movie_metadata_dropped['4. Movie release date'].str[:4]

#We group the data by the release dates and take the mean box office revenue ($) of each year except the first outlier (year 1010)
grouped=movie_metadata_dropped.groupby(by='4. Movie release date')['5. Movie box office revenue'].mean()[1:]
index_values=grouped.index.values.tolist()
index_values = [int(s) for s in index_values]

plt.figure(figsize=(12, 6))
plt.bar(index_values, grouped)
plt.xticks(np.arange(min(index_values), max(index_values)+1, 5),rotation=45)
plt.xlabel("Years")
plt.ylabel("Box office revenues ($)")
plt.title("The mean box office revenue of movies per year")
plt.show()

# %%
# Verify if the value of 1010 it was a error from both data sets

# Create a copy
movie_metadata_ex = movie_metadata.copy()
character_metadata_ex = character_metadata.copy()

# See where is equal to 1010
ola = (movie_metadata_ex['4. Movie release date'].dropna()).astype(str).str[:4] == "1010"
np.where(ola)[0]
print(ola[57570:57571])

# Search for the Movie ID of this film
movie_ID_1010 = movie_metadata_ex.iloc[62835,:]['1. Wikipedia movie ID']

# Verify if on the other data frame has the same error
character_metadata_ex[character_metadata_ex['1. Wikipedia movie ID'] == movie_ID_1010]
# Out:
# 62835    True
# Name: 4. Movie release date, dtype: bool
#        1. Wikipedia movie ID 2. Freebase movie ID 3. Movie release date  \
# 67623               29666067           /m/0fphzrf            1010-12-02
# 67624               29666067           /m/0fphzrf            1010-12-02
# 67625               29666067           /m/0fphzrf            1010-12-02
# 67626               29666067           /m/0fphzrf            1010-12-02
# 67627               29666067           /m/0fphzrf            1010-12-02
# 67628               29666067           /m/0fphzrf            1010-12-02
# 67629               29666067           /m/0fphzrf            1010-12-02
# 67630               29666067           /m/0fphzrf            1010-12-02
# 67631               29666067           /m/0fphzrf            1010-12-02
# 67632               29666067           /m/0fphzrf            1010-12-02
# 67633               29666067           /m/0fphzrf            1010-12-02
# ...

# %%
# Create a copy
character_metadata_ex = character_metadata.copy()

#We then take the first 4 digits of the year which correspond to the year
character_metadata_ex.loc[:, '3. Movie release date']=character_metadata_ex['3. Movie release date'].str[:4]

movies = character_metadata_ex.groupby(['3. Movie release date', '6. Actor gender']).size().unstack(fill_value = 0)

# Takes out the 1010
movies = movies[1:]

# Add 3 columns, one with the sum per year of M & F, the second with the percentage of F and the third the percentage of M 
movies['Total'] = movies['M'] + movies['F']
movies['Percentage of F'] = movies['F']/movies['Total']
movies['Percentage of M'] = movies['M']/movies['Total']

# Plotting the histogram
sns.set(style = "whitegrid")
plt.figure(figsize = (10, 6))

# Bar for 'M'
sns.histplot(x = '3. Movie release date', y = 'Percentage of F', data = movies, color='pink', label='Female')

# Bar for 'F'
sns.histplot(x = '3. Movie release date', y = 'Percentage of M', data = movies, color='blue', label='Male')

plt.title('Percentage of Males and Females Over the Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
#plt.xticks(np.arange(movies.iloc[0]['3. Movie release date'],1950,10))
plt.show()

#character_metadata[character_metadata['1. Wikipedia movie ID'] == 28308153]
#display(movies.loc[28308153])

#display(character_metadata_ex)
display(movies.iloc[0])
# Out:
# 6. Actor gender
# F                  2.0
# M                  2.0
# Total              4.0
# Percentage of F    0.5
# Percentage of M    0.5
# Name: 1888, dtype: float64

# %%
# Create a copy
character_metadata_ex = character_metadata.copy()

#We then take the first 4 digits of the year which correspond to the year
character_metadata_ex.loc[:, '3. Movie release date']=character_metadata_ex['3. Movie release date'].str[:4]

character_metadata_ex['year_group'] = character_metadata_ex['3. Movie release date'] // 10 * 10

movies = character_metadata_ex.groupby(['year group', '6. Actor gender']).size().unstack(fill_value = 0)

# Takes out the 1010
movies = movies[1:]

# Add 3 columns, one with the sum per year of M & F, the second with the percentage of F and the third the percentage of M 
movies['Total'] = movies['M'] + movies['F']
movies['Percentage of F'] = movies['F']/movies['Total']
movies['Percentage of M'] = movies['M']/movies['Total']

# Plotting the histogram
sns.set(style = "whitegrid")
plt.figure(figsize = (10, 6))

# Bar for 'M'
plt.hist(x = '3. Movie release date', y = 'Percentage of F', data = movies, color='pink', label='Female')

# Bar for 'F'
plt.hist(x = '3. Movie release date', y = 'Percentage of M', data = movies, color='blue', label='Male')

plt.title('Percentage of Males and Females Over the Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend()
plt.show()
#character_metadata[character_metadata['1. Wikipedia movie ID'] == 28308153]
#display(movies.loc[28308153])

#display(character_metadata_ex)
display(movies)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/core/computation/expressions.py:243, in evaluate(op, a, b, use_numexpr)
#     242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
# --> 243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/opt/anaconda3/envs/ada/lib/python3.9/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for //: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
# ...

# %%
# Complementing the data 

# Create a copy
character_metadata_ex = character_metadata.copy()

# Data frame to see the age of the actor
character_age = character_metadata_ex.iloc[:,[2,4,9]]

# Sum of Nans in each row
nans_character_age = character_age.isnull().sum(axis=1)

#for i in range(len(nans_character_age)):
 #   if nans_character_age[i] == 1
  #      if character_age[i,:]['3. Movie release date'].isnan()
   #         do this
    #    elif 
     #       character_age[i,:]['5. Actor date of birth']
      #  else
            
        
        
# Take off the nan values and just see the first 4 numbers (years)
year_release = (character_age['3. Movie release date'].dropna()).astype(str).str[:4]

# Count the numbers that are equal
#year_release = year_release.value_counts()
character_age[character_age['3. Movie release date'].isna()]
#

# Count NaN on single column of DataFrame
#for i in range(len(character_age)):
    #result = character_age.iloc[i,:].isna().sum()
#['3. Movie release date'].dropna

#display(nans_character_age)    
#display(year_release)
#display(character_age)
#display(character_age.iloc[334:340,:]['3. Movie release date'])
# Out:
#        3. Movie release date 5. Actor date of birth  \
# 336                      NaN             1953-03-16
# 493                      NaN             1950-12-12
# 518                      NaN             1908-05-30
# 519                      NaN             1964-01-15
# 520                      NaN             1972-07-18
# ...                      ...                    ...
# 450333                   NaN                    NaN
# 450493                   NaN             1970-03-23
# 450494                   NaN             1965-09-03
# 450495                   NaN             1967-04-02
# 450502                   NaN             1914-07-31
#
#         10. Actor age at movie release
# 336                                NaN
# 493                                NaN
# 518                                NaN
# 519                                NaN
# 520                                NaN
# ...                                ...
# 450333                             NaN
# ...
